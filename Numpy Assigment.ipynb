# %% [markdown]
# # Numpy Assigment

# %%
import cv2
import glob
import numpy as np

# %%
dataMatrix = []
images = glob.glob ("C:\\Users\\CS\\Desktop\\14 Agu 2017\\*.PNG")
for image in images:
    print(image)
    image = cv2.imread (image)
    dataMatrix.append (image)
# Out:
# C:\Users\CS\Desktop\14 Agu 2017\2000px-Flag_of_Pakistan.svg.png
# C:\Users\CS\Desktop\14 Agu 2017\20160729111220.png
# C:\Users\CS\Desktop\14 Agu 2017\a (11).png
# C:\Users\CS\Desktop\14 Agu 2017\a (47).png
# C:\Users\CS\Desktop\14 Agu 2017\a (5).png
# C:\Users\CS\Desktop\14 Agu 2017\a (54).png
# C:\Users\CS\Desktop\14 Agu 2017\a (58).png
# C:\Users\CS\Desktop\14 Agu 2017\a (59).png
# C:\Users\CS\Desktop\14 Agu 2017\a (60).png
# C:\Users\CS\Desktop\14 Agu 2017\a (63).png
# C:\Users\CS\Desktop\14 Agu 2017\a (64).png
# C:\Users\CS\Desktop\14 Agu 2017\a (65).png
# C:\Users\CS\Desktop\14 Agu 2017\a (9).png
# C:\Users\CS\Desktop\14 Agu 2017\happy-independence-day-of-pakistan-14-august-1947.png
# C:\Users\CS\Desktop\14 Agu 2017\i-love-pakistan-facebook-banner.png
# C:\Users\CS\Desktop\14 Agu 2017\jashane-azadi-mubarak-quotes-580x370.png
# C:\Users\CS\Desktop\14 Agu 2017\my05.png
# C:\Users\CS\Desktop\14 Agu 2017\my06.png
# C:\Users\CS\Desktop\14 Agu 2017\Pak.png
# ...

# %%
print('X_data shape:', np.array(dataMatrix).shape)
# Out:
# X_data shape: (20,)

# %%
dataMatrix
# Out:
# [array([[[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [ 28,  65,   1],
#          [ 28,  65,   1],
#          [ 28,  65,   1]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [ 28,  65,   1],
#          [ 28,  65,   1],
#          [ 28,  65,   1]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [ 28,  65,   1],
#          [ 28,  65,   1],
#          [ 28,  65,   1]],
#
#         ...,
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [ 28,  65,   1],
#          [ 28,  65,   1],
#          [ 28,  65,   1]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [ 28,  65,   1],
#          [ 28,  65,   1],
#          [ 28,  65,   1]],
#
#         [[255, 255, 255],
# ...
